# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import ArrayType, IntegerType, StructType, StructField
from pyspark.sql.functions import regexp_extract, lit, split, col

# %%
from datetime import datetime
import requests
import json
import os
import configparser
from pathlib import Path

# %%
spark = SparkSession \
        .builder \
        .master('local') \
        .appName('tempera_obs') \
        .config("spark.driver.extraClassPath", "/Users/mdgome/Downloads/mysql-connector-java-8.0.28/mysql-connector-java-8.0.28.jar") \
        .getOrCreate()
#        .master('spark://hadoop01:7077') \
       # .config("spark.driver.extraClassPath", "/hadoop/jupyter_dir/jar/mysql-connector-java-8.0.28/mysql-connector-java-8.0.28.jar") \
            # .config("spark.driver.extraClassPath", "hdfs:///spark3-jars/mysql-connector-java-8.0.28.jar") \
# Out:
# 22/03/09 00:09:22 WARN Utils: Your hostname, Jungminui-MacBookPro.local resolves to a loopback address: 127.0.0.1; using 172.30.1.27 instead (on interface en0)
# 22/03/09 00:09:22 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/03/09 00:09:23 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/03/09 00:09:23 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
now_datetime=datetime.now().strftime('%Y.%m.%d')
now_datetime # 디버깅 용
# Out:
# '2022.03.09'

# %%
config = configparser.ConfigParser()
config.read(Path("./config/config.ini"),encoding='utf-8')
# Out:
# ['config/config.ini']

# %%
service_key=config['api']['service_key']
url="http://www.khoa.go.kr/api/oceangrid/ObsServiceObj/search.do?ServiceKey="+service_key+"&ResultType=json"
url # 디버깅용
# Out:
# 'http://www.khoa.go.kr/api/oceangrid/ObsServiceObj/search.do?ServiceKey=1LJG14JWnAylzKi5GvmuGg==&ResultType=json'

# %%
response = requests.get(url).json()
response['result']['data']
# Out:
# [{'obs_post_id': 'DT_0063',
#   'obs_lat': '35.024178',
#   'data_type': '조위관측소',
#   'obs_post_name': '가덕도',
#   'obs_lon': '128.810933',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0032',
#   'obs_lat': '37.731944',
#   'data_type': '조위관측소',
#   'obs_post_name': '강화대교',
#   'obs_lon': '126.522222',
#   'obs_object': '조위,기압'},
#  {'obs_post_id': 'DT_0031',
#   'obs_lat': '34.028333',
#   'data_type': '조위관측소',
#   'obs_post_name': '거문도',
#   'obs_lon': '127.308889',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0029',
#   'obs_lat': '34.801389',
#   'data_type': '조위관측소',
#   'obs_post_name': '거제도',
#   'obs_lon': '128.699167',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0058',
#   'obs_lat': '37.560833',
#   'data_type': '조위관측소',
#   'obs_post_name': '경인항',
#   'obs_lon': '126.601111',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0026',
#   'obs_lat': '34.481111',
#   'data_type': '조위관측소',
#   'obs_post_name': '고흥발포',
#   'obs_lon': '127.342778',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0049',
#   'obs_lat': '34.903672',
#   'data_type': '조위관측소',
#   'obs_post_name': '광양',
#   'obs_lon': '127.754836',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0018',
#   'obs_lat': '35.975556',
#   'data_type': '조위관측소',
#   'obs_post_name': '군산',
#   'obs_lon': '126.563056',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0017',
#   'obs_lat': '37.0075',
#   'data_type': '조위관측소',
#   'obs_post_name': '대산',
#   'obs_lon': '126.352778',
#   'obs_object': '조위,수온,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0065',
#   'obs_lat': '37.226333',
#   'data_type': '조위관측소',
#   'obs_post_name': '덕적도',
#   'obs_lon': '126.156556',
#   'obs_object': '기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0057',
#   'obs_lat': '37.494722',
#   'data_type': '조위관측소',
#   'obs_post_name': '동해항',
#   'obs_lon': '129.143889',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0062',
#   'obs_lat': '35.1975',
#   'data_type': '조위관측소',
#   'obs_post_name': '마산',
#   'obs_lon': '128.576389',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0023',
#   'obs_lat': '33.214444',
#   'data_type': '조위관측소',
#   'obs_post_name': '모슬포',
#   'obs_lon': '126.251111',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0007',
#   'obs_lat': '34.779722',
#   'data_type': '조위관측소',
#   'obs_post_name': '목포',
#   'obs_lon': '126.375556',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0006',
#   'obs_lat': '37.550278',
#   'data_type': '조위관측소',
#   'obs_post_name': '묵호',
#   'obs_lon': '129.116389',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0025',
#   'obs_lat': '36.406389',
#   'data_type': '조위관측소',
#   'obs_post_name': '보령',
#   'obs_lon': '126.486111',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0005',
#   'obs_lat': '35.096389',
#   'data_type': '조위관측소',
#   'obs_post_name': '부산',
#   'obs_lon': '129.035278',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0056',
#   'obs_lat': '35.0775',
#   'data_type': '조위관측소',
#   'obs_post_name': '부산항신항',
#   'obs_lon': '128.786944',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0061',
#   'obs_lat': '34.924167',
#   'data_type': '조위관측소',
#   'obs_post_name': '삼천포',
#   'obs_lon': '128.069722',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0010',
#   'obs_lat': '33.24',
#   'data_type': '조위관측소',
#   'obs_post_name': '서귀포',
#   'obs_lon': '126.561667',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0051',
#   'obs_lat': '36.1288888888889',
#   'data_type': '조위관측소',
#   'obs_post_name': '서천마량',
#   'obs_lon': '126.495277777778',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0022',
#   'obs_lat': '33.474722',
#   'data_type': '조위관측소',
#   'obs_post_name': '성산포',
#   'obs_lon': '126.927778',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0012',
#   'obs_lat': '38.207222',
#   'data_type': '조위관측소',
#   'obs_post_name': '속초',
#   'obs_lon': '128.594167',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0008',
#   'obs_lat': '37.192222',
#   'data_type': '조위관측소',
#   'obs_post_name': '안산',
#   'obs_lon': '126.647222',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0067',
#   'obs_lat': '36.6746388888889',
#   'data_type': '조위관측소',
#   'obs_post_name': '안흥',
#   'obs_lon': '126.129555555556',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0037',
#   'obs_lat': '36.117222',
#   'data_type': '조위관측소',
#   'obs_post_name': '어청도',
#   'obs_lon': '125.984722',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0016',
#   'obs_lat': '34.747222',
#   'data_type': '조위관측소',
#   'obs_post_name': '여수',
#   'obs_lon': '127.765556',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0092',
#   'obs_lat': '34.661944',
#   'data_type': '조위관측소',
#   'obs_post_name': '여호항',
#   'obs_lon': '127.469167',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0003',
#   'obs_lat': '35.426111',
#   'data_type': '조위관측소',
#   'obs_post_name': '영광',
#   'obs_lon': '126.420556',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0044',
#   'obs_lat': '37.545556',
#   'data_type': '조위관측소',
#   'obs_post_name': '영종대교',
#   'obs_lon': '126.584444',
#   'obs_object': '조위,기압'},
#  {'obs_post_id': 'DT_0043',
#   'obs_lat': '37.2386111111111',
#   'data_type': '조위관측소',
#   'obs_post_name': '영흥도',
#   'obs_lon': '126.428611111111',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0027',
#   'obs_lat': '34.315556',
#   'data_type': '조위관측소',
#   'obs_post_name': '완도',
#   'obs_lon': '126.759722',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0013',
#   'obs_lat': '37.491389',
#   'data_type': '조위관측소',
#   'obs_post_name': '울릉도',
#   'obs_lon': '130.913611',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0020',
#   'obs_lat': '35.501944',
#   'data_type': '조위관측소',
#   'obs_post_name': '울산',
#   'obs_lon': '129.387222',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0068',
#   'obs_lat': '35.6180844444444',
#   'data_type': '조위관측소',
#   'obs_post_name': '위도',
#   'obs_lon': '126.301815833333',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0001',
#   'obs_lat': '37.451944',
#   'data_type': '조위관측소',
#   'obs_post_name': '인천',
#   'obs_lon': '126.592222',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0052',
#   'obs_lat': '37.3380555555556',
#   'data_type': '조위관측소',
#   'obs_post_name': '인천송도',
#   'obs_lon': '126.586111111111',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0024',
#   'obs_lat': '36.006944',
#   'data_type': '조위관측소',
#   'obs_post_name': '장항',
#   'obs_lon': '126.6875',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0004',
#   'obs_lat': '33.5275',
#   'data_type': '조위관측소',
#   'obs_post_name': '제주',
#   'obs_lon': '126.543056',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0028',
#   'obs_lat': '34.377778',
#   'data_type': '조위관측소',
#   'obs_post_name': '진도',
#   'obs_lon': '126.308611',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0021',
#   'obs_lat': '33.961944',
#   'data_type': '조위관측소',
#   'obs_post_name': '추자도',
#   'obs_lon': '126.300278',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0050',
#   'obs_lat': '36.9130555555556',
#   'data_type': '조위관측소',
#   'obs_post_name': '태안',
#   'obs_lon': '126.238888888889',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0014',
#   'obs_lat': '34.827778',
#   'data_type': '조위관측소',
#   'obs_post_name': '통영',
#   'obs_lon': '128.434722',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0002',
#   'obs_lat': '36.966944',
#   'data_type': '조위관측소',
#   'obs_post_name': '평택',
#   'obs_lon': '126.822778',
#   'obs_object': '조위,수온,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0091',
#   'obs_lat': '36.047128',
#   'data_type': '조위관측소',
#   'obs_post_name': '포항',
#   'obs_lon': '129.383806',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0066',
#   'obs_lat': '35.167667',
#   'data_type': '조위관측소',
#   'obs_post_name': '향화도',
#   'obs_lon': '126.359556',
#   'obs_object': '조위,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0011',
#   'obs_lat': '36.6775',
#   'data_type': '조위관측소',
#   'obs_post_name': '후포',
#   'obs_lon': '129.453056',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0035',
#   'obs_lat': '34.684167',
#   'data_type': '조위관측소',
#   'obs_post_name': '흑산도',
#   'obs_lon': '125.435556',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향'},
#  {'obs_post_id': 'DT_0042',
#   'obs_lat': '34.7047222222222',
#   'data_type': '해양관측소',
#   'obs_post_name': '교본초',
#   'obs_lon': '128.306388888889',
#   'obs_object': '조위,기온,기압,풍속,풍향,파고'},
#  {'obs_post_id': 'DT_0041',
#   'obs_lat': '34.0983333333333',
#   'data_type': '해양관측소',
#   'obs_post_name': '복사초',
#   'obs_lon': '126.168333333333',
#   'obs_object': '조위,기온,기압,풍속,풍향,파고'},
#  {'obs_post_id': 'DT_0039',
#   'obs_lat': '36.7191666666667',
#   'data_type': '해양관측소',
#   'obs_post_name': '왕돌초',
#   'obs_lon': '129.7325',
#   'obs_object': '실시간제공데이터 항목 없음'},
#  {'obs_post_id': 'IE_0060',
#   'obs_lat': '32.1227777777778',
#   'data_type': '해양과학기지',
#   'obs_post_name': '이어도',
#   'obs_lon': '125.182222222222',
#   'obs_object': '조위,수온,염분,기온,기압,풍속,풍향,파고'},
#  {'obs_post_id': 'IE_0062',
#   'obs_lat': '37.423056',
#   'data_type': '해양과학기지',
#   'obs_post_name': '옹진소청초',
#   'obs_lon': '124.738056',
#   'obs_object': '조위,수온,기온,기압,풍속,풍향,파고'},
#  {'obs_post_id': 'IE_0061',
#   'obs_lat': '33.941944',
#   'data_type': '해양과학기지',
#   'obs_post_name': '신안가거초',
#   'obs_lon': '124.592778',
#   'obs_object': '조위,기온,기압,풍속,풍향,파고'},
#  {'obs_post_id': 'TW_0089',
#   'obs_lat': '37.808972',
#   'data_type': '해양관측부이',
#   'obs_post_name': '경포대해수욕장',
#   'obs_lon': '128.931889',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'HB_0007',
#   'obs_lat': '37.019444',
#   'data_type': '해양관측부이',
#   'obs_post_name': '한수원_온양',
#   'obs_lon': '129.425',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'HB_0008',
#   'obs_lat': '37.1',
#   'data_type': '해양관측부이',
#   'obs_post_name': '한수원_덕천',
#   'obs_lon': '129.404167',
#   'obs_object': '수온,기온,기압,풍속,풍향,유속,유향'},
#  {'obs_post_id': 'HB_0009',
#   'obs_lat': '37.119167',
#   'data_type': '해양관측부이',
#   'obs_post_name': '한수원_나곡',
#   'obs_lon': '129.395833',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0079',
#   'obs_lat': '35.652472',
#   'data_type': '해양관측부이',
#   'obs_post_name': '상왕등도',
#   'obs_lon': '126.19425',
#   'obs_object': '수온,기온,기압,풍속,풍향,유속,유향'},
#  {'obs_post_id': 'TW_0080',
#   'obs_lat': '34.5430555555556',
#   'data_type': '해양관측부이',
#   'obs_post_name': '우이도',
#   'obs_lon': '125.802777777778',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'TW_0081',
#   'obs_lat': '34.258722',
#   'data_type': '해양관측부이',
#   'obs_post_name': '생일도',
#   'obs_lon': '126.960277',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'TW_0082',
#   'obs_lat': '37.006722',
#   'data_type': '해양관측부이',
#   'obs_post_name': '태안항',
#   'obs_lon': '126.270222',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0083',
#   'obs_lat': '34.794722',
#   'data_type': '해양관측부이',
#   'obs_post_name': '여수항',
#   'obs_lon': '127.808055',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0084',
#   'obs_lat': '34.773333',
#   'data_type': '해양관측부이',
#   'obs_post_name': '통영항',
#   'obs_lon': '128.46',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0092',
#   'obs_lat': '35.3025',
#   'data_type': '해양관측부이',
#   'obs_post_name': '임랑해수욕장',
#   'obs_lon': '129.2925',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'SF_0001',
#   'obs_lat': '35.09175',
#   'data_type': '해양관측부이',
#   'obs_post_name': '부산항',
#   'obs_lon': '129.08525',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0078',
#   'obs_lat': '34.325083',
#   'data_type': '해양관측부이',
#   'obs_post_name': '완도항',
#   'obs_lon': '126.763194',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0087',
#   'obs_lat': '35.09175',
#   'data_type': '해양관측부이',
#   'obs_post_name': '부산항',
#   'obs_lon': '129.08525',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0090',
#   'obs_lat': '35.164722',
#   'data_type': '해양관측부이',
#   'obs_post_name': '송정해수욕장',
#   'obs_lon': '129.219444',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'TW_0074',
#   'obs_lat': '34.859722',
#   'data_type': '해양관측부이',
#   'obs_post_name': '광양항',
#   'obs_lon': '127.792777',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'HB_0001',
#   'obs_lat': '35.182444',
#   'data_type': '해양관측부이',
#   'obs_post_name': '한수원_기장',
#   'obs_lon': '129.23525',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'HB_0002',
#   'obs_lat': '35.3185',
#   'data_type': '해양관측부이',
#   'obs_post_name': '한수원_고리',
#   'obs_lon': '129.314722',
#   'obs_object': '수온,기온,기압,풍속,풍향,유속,유향'},
#  {'obs_post_id': 'HB_0003',
#   'obs_lat': '35.384722',
#   'data_type': '해양관측부이',
#   'obs_post_name': '한수원_진하',
#   'obs_lon': '129.368056',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0062',
#   'obs_lat': '35.148972',
#   'data_type': '해양관측부이',
#   'obs_post_name': '해운대해수욕장',
#   'obs_lon': '129.170166',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'TW_0069',
#   'obs_lat': '36.274111',
#   'data_type': '해양관측부이',
#   'obs_post_name': '대천해수욕장',
#   'obs_lon': '126.457805',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'TW_0070',
#   'obs_lat': '37.136666',
#   'data_type': '해양관측부이',
#   'obs_post_name': '평택당진항',
#   'obs_lon': '126.540833',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0072',
#   'obs_lat': '35.984166',
#   'data_type': '해양관측부이',
#   'obs_post_name': '군산항',
#   'obs_lon': '126.50875',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0077',
#   'obs_lat': '37.523388',
#   'data_type': '해양관측부이',
#   'obs_post_name': '경인항',
#   'obs_lon': '126.592083',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0075',
#   'obs_lat': '33.2345',
#   'data_type': '해양관측부이',
#   'obs_post_name': '중문해수욕장',
#   'obs_lon': '126.409555',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'TW_0076',
#   'obs_lat': '37.389444',
#   'data_type': '해양관측부이',
#   'obs_post_name': '인천항',
#   'obs_lon': '126.533055',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0088',
#   'obs_lat': '35.052805',
#   'data_type': '해양관측부이',
#   'obs_post_name': '감천항',
#   'obs_lon': '129.003083',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0085',
#   'obs_lat': '35.103194',
#   'data_type': '해양관측부이',
#   'obs_post_name': '마산항',
#   'obs_lon': '128.631833',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0091',
#   'obs_lat': '38.1225',
#   'data_type': '해양관측부이',
#   'obs_post_name': '낙산해수욕장',
#   'obs_lon': '128.650556',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'TW_0086',
#   'obs_lat': '35.043777',
#   'data_type': '해양관측부이',
#   'obs_post_name': '부산항신항',
#   'obs_lon': '128.76175',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'SF_0005',
#   'obs_lat': '35.984166',
#   'data_type': '해양관측부이',
#   'obs_post_name': '군산항',
#   'obs_lon': '126.50875',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'TW_0093',
#   'obs_lat': '38.198611',
#   'data_type': '해양관측부이',
#   'obs_post_name': '속초해수욕장',
#   'obs_lon': '128.631389',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'TW_0094',
#   'obs_lat': '37.593666',
#   'data_type': '해양관측부이',
#   'obs_post_name': '망상해수욕장',
#   'obs_lon': '129.090091',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'KG_0021',
#   'obs_lat': '32.090416',
#   'data_type': '해양관측부이',
#   'obs_post_name': '제주남부',
#   'obs_lon': '126.965861',
#   'obs_object': '수온,유속,유향'},
#  {'obs_post_id': 'KG_0024',
#   'obs_lat': '34.919',
#   'data_type': '해양관측부이',
#   'obs_post_name': '대한해협',
#   'obs_lon': '129.12125',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'KG_0025',
#   'obs_lat': '34.222472',
#   'data_type': '해양관측부이',
#   'obs_post_name': '남해동부',
#   'obs_lon': '128.419027',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'KG_0028',
#   'obs_lat': '33.7001111111111',
#   'data_type': '해양관측부이',
#   'obs_post_name': '제주해협',
#   'obs_lon': '126.5905',
#   'obs_object': '실시간제공데이터 항목 없음'},
#  {'obs_post_id': 'KG_0101',
#   'obs_lat': '38.007361',
#   'data_type': '해양관측부이',
#   'obs_post_name': '울릉도북동',
#   'obs_lon': '131.552583',
#   'obs_object': '수온,기온,기압,풍속,풍향,파고,유속,유향'},
#  {'obs_post_id': 'KG_0102',
#   'obs_lat': '37.742722',
#   'data_type': '해양관측부이',
#   'obs_post_name': '울릉도북서',
#   'obs_lon': '130.601194',
#   'obs_object': '실시간제공데이터 항목 없음'}]

# %%
type(response)
# Out:
# dict

# %%
df = spark.createDataFrame(response["result"]["data"])
df.show(5)
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +----------+---------+----------+----------------------------------+-----------+-------------+
# | data_type|  obs_lat|   obs_lon|                        obs_object|obs_post_id|obs_post_name|
# +----------+---------+----------+----------------------------------+-----------+-------------+
# |조위관측소|35.024178|128.810933|조위,수온,염분,기온,기압,풍속,풍향|    DT_0063|       가덕도|
# |조위관측소|37.731944|126.522222|                         조위,기압|    DT_0032|     강화대교|
# |조위관측소|34.028333|127.308889|조위,수온,염분,기온,기압,풍속,풍향|    DT_0031|       거문도|
# |조위관측소|34.801389|128.699167|조위,수온,염분,기온,기압,풍속,풍향|    DT_0029|       거제도|
# |조위관측소|37.560833|126.601111|          조위,기온,기압,풍속,풍향|    DT_0058|       경인항|
# +----------+---------+----------+----------------------------------+-----------+-------------+
# only showing top 5 rows

# %%
config = configparser.ConfigParser()
config.read(Path("./config/config.ini"),encoding='utf-8')
# config.read(os.getcwd()+os.sep+'config'+os.sep+'config.ini',encoding='utf-8')

user = config['dev_mysql']['user']
password = config['dev_mysql']['password']
host = config['dev_mysql']['host']
port = config['dev_mysql']['port']
dbname = config['dev_mysql']['dbname']
url = config['dev_mysql']['url'].format(host=host,port=port,dbname=dbname)
# dbtable = config['dev_mysql']['dbtable']

# %%
df.write.format('jdbc').options(
    url=url,
    driver='com.mysql.jdbc.Driver',
    dbtable='obs_info',
    user=user,
    password=password).mode('overwrite').save()
# Out:
# Loading class `com.mysql.jdbc.Driver'. This is deprecated. The new driver class is `com.mysql.cj.jdbc.Driver'. The driver is automatically registered via the SPI and manual loading of the driver class is generally unnecessary.

# %%
# !hdfs dfs -ls /middle_project
# Out:
# Found 2 items
# drwxr-xr-x   - hadoop supergroup          0 2022-02-26 05:47 /middle_project/2022.02.26_obs_info.csv
# drwxr-xr-x   - hadoop supergroup          0 2022-03-02 17:35 /middle_project/2022.03.02_obs_info.csv

# %%
file_name = "hdfs:///middle_project/"+now_datetime+"_obs_info.csv"
file_name
# Out:
# 'hdfs:///middle_project/2022.03.02_obs_info.csv'

# %%
# df.write.csv(file_name,header=True)
df.coalesce(1).write.format('com.databricks.spark.csv').save(file_name,header = 'true')

# %%
test_df = spark.read.csv(file_name)

# %%
test_df.show(5)
# Out:
# +----------+---------+----------+----------------------------------+-----------+-------------+
# |       _c0|      _c1|       _c2|                               _c3|        _c4|          _c5|
# +----------+---------+----------+----------------------------------+-----------+-------------+
# | data_type|  obs_lat|   obs_lon|                        obs_object|obs_post_id|obs_post_name|
# |조위관측소|35.024178|128.810933|조위,수온,염분,기온,기압,풍속,풍향|    DT_0063|       가덕도|
# |조위관측소|37.731944|126.522222|                         조위,기압|    DT_0032|     강화대교|
# |조위관측소|34.028333|127.308889|조위,수온,염분,기온,기압,풍속,풍향|    DT_0031|       거문도|
# |조위관측소|34.801389|128.699167|조위,수온,염분,기온,기압,풍속,풍향|    DT_0029|       거제도|
# +----------+---------+----------+----------------------------------+-----------+-------------+
# only showing top 5 rows

# %%
spark.stop()
