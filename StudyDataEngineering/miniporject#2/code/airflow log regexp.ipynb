# %%
# coding=utf8
# the above tag defines encoding for this document and is for Python 2.x compatibility

import re

regex = r"^\[(\d+-\d+-\d+\s\d+:\d+:\d+,\d+)\] \{\S+\} (DEBUG|INFO|WARN|FATAL|ERROR|TRACE)([^][]*)|(.*)"

test_str = ("[2022-01-19 11:55:04,219] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 5.120 seconds\n"
	"[2022-01-19 11:55:34,413] {processor.py:163} INFO - Started process (PID=451) to work on /opt/airflow/dags/MySQL_to_CSV.py\n"
	"[2022-01-19 11:55:34,417] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue\n"
	"[2022-01-19 12:09:57,089] {logging_mixin.py:109} INFO - [2022-01-19 12:09:57,088] {dag.py:2914} INFO - Setting next_dagrun for second_assingnment to 2022-01-19T12:00:00+00:00\n"
	"[2022-01-19 12:09:57,101] {processor.py:174} ERROR - Got an exception! Propagating...\n"
	"Traceback (most recent call last):\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/airflow/dag_processing/processor.py\", line 168, in _run_file_processor\n"
	"    callback_requests=callback_requests,\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/session.py\", line 70, in wrapper\n"
	"    return func(*args, session=session, **kwargs)\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/airflow/dag_processing/processor.py\", line 641, in process_file\n"
	"    dagbag.sync_to_db()\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/session.py\", line 70, in wrapper\n"
	"    return func(*args, session=session, **kwargs)\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py\", line 608, in sync_to_db\n"
	"    for attempt in run_with_db_retries(logger=self.log):\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/tenacity/__init__.py\", line 382, in __iter__\n"
	"    do = self.iter(retry_state=retry_state)\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/tenacity/__init__.py\", line 349, in iter\n"
	"    return fut.result()\n"
	"  File \"/usr/local/lib/python3.7/concurrent/futures/_base.py\", line 428, in result\n"
	"    return self.__get_result()\n"
	"  File \"/usr/local/lib/python3.7/concurrent/futures/_base.py\", line 384, in __get_result\n"
	"    raise self._exception\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py\", line 622, in sync_to_db\n"
	"    DAG.bulk_write_to_db(self.dags.values(), session=session)\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/session.py\", line 67, in wrapper\n"
	"    return func(*args, **kwargs)\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dag.py\", line 2470, in bulk_write_to_db\n"
	"    DagCode.bulk_sync_to_db(filelocs, session=session)\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/session.py\", line 67, in wrapper\n"
	"    return func(*args, **kwargs)\n"
	"  File \"/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagcode.py\", line 113, in bulk_sync_to_db\n"
	"    os.path.getmtime(correct_maybe_zipped(fileloc)), tz=timezone.utc\n"
	"  File \"/usr/local/lib/python3.7/genericpath.py\", line 55, in getmtime\n"
	"    return os.stat(filename).st_mtime\n"
	"FileNotFoundError: [Errno 2] No such file or directory: '/opt/airflow/dags/MySQL_to_CSV.py'\n"
	"[2022-01-19 12:10:09,495] {processor.py:163} INFO - Started process (PID=3925) to work on /opt/airflow/dags/MySQL_to_CSV.py")

matches = re.finditer(regex, test_str, re.MULTILINE)

for matchNum, match in enumerate(matches, start=1):
    
    print ("Match {matchNum} was found at {start}-{end}: {match}".format(matchNum = matchNum, start = match.start(), end = match.end(), match = match.group()))
    
    for groupNum in range(0, len(match.groups())):
        groupNum = groupNum + 1
        
        print ("Group {groupNum} found at {start}-{end}: {group}".format(groupNum = groupNum, start = match.start(groupNum), end = match.end(groupNum), group = match.group(groupNum)))

# Note: for Python 2.7 compatibility, use ur"" to prefix the regex and u"" to prefix the test string and substitution.
# Out:
# Match 1 was found at 0-116: [2022-01-19 11:55:04,219] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 5.120 seconds
#
# Group 1 found at 1-24: 2022-01-19 11:55:04,219
# Group 2 found at 45-49: INFO
# Group 3 found at 49-116:  - Processing /opt/airflow/dags/MySQL_to_CSV.py took 5.120 seconds
#
# Group 4 found at -1--1: None
# Match 2 was found at 116-239: [2022-01-19 11:55:34,413] {processor.py:163} INFO - Started process (PID=451) to work on /opt/airflow/dags/MySQL_to_CSV.py
#
# Group 1 found at 117-140: 2022-01-19 11:55:34,413
# Group 2 found at 161-165: INFO
# Group 3 found at 165-239:  - Started process (PID=451) to work on /opt/airflow/dags/MySQL_to_CSV.py
#
# Group 4 found at -1--1: None
# Match 3 was found at 239-360: [2022-01-19 11:55:34,417] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue
#
# Group 1 found at 240-263: 2022-01-19 11:55:34,417
# Group 2 found at 284-288: INFO
# ...

# %%
# !ls
# Out:
# Untitled.ipynb           airflow log regexp.ipynb

# %%
# !pwd
# Out:
# /Users/mdgome/workspace/study/StudyDataEngineering/StudyDataEngineering/miniporject#2/code
