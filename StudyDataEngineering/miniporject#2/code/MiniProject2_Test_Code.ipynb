# %% [markdown]
# ## find Spark

# %%
import findspark
findspark.init() # find spark

# %% [markdown]
# ## import

# %%
from pyspark.sql import SparkSession
import re
import findspark
import json
import pandas as pd 
from elasticsearch import Elasticsearch
from elasticsearch import helpers
from __future__ import print_function

# %% [markdown]
# ## 함수 정의

# %% [markdown]
# ### 1. Log Data Parsing 함수

# %%
# log data parsing 
def parsing(row):
    row_ = dict()
    ts_pattern = re.compile( r"\[(\d+-\d+-\d+) ((\d+:\d+:\d+),\d+)\]") 

    if "INFO" in row :
        row_["Timestamp"] = ts_pattern.match(row).group(1) +" "+ ts_pattern.match(row).group(3)
        row_["Status"] = "INFO" # Status Parsing 
        row_["Message"] = row.split("INFO - ")[1] # Message Parsing        
        
    elif "WARNING" in row :
        row_["Timestamp"] = ts_pattern.match(row).group(1) +" "+ ts_pattern.match(row).group(3)
        row_["Status"] = "WARNING" # Status Parsing 
        row_["Message"] = row.split("WARNING - ")[1] # Message Parsing 
        
        
    elif "ERROR" in row :
        row_["Timestamp"] = ts_pattern.match(row).group(1) +" "+ ts_pattern.match(row).group(3)
        row_["Status"] = "ERROR" # Status Parsing 
        row_["Message"] = row.split("ERROR - ")[1] # Message Parsing   
    
    return row_

# %% [markdown]
# ### 2. Elastic Search에 bulk로 저장하는 함수

# %%
def bulk_insert(host, port, df, index):
    es = Elasticsearch(host = host,port = port)

    data = [
      {
        "_index": index,
        "_source": {
            "datetime": x[0],
            "log-level": x[1],
            "message":x[2]}
      }
        for x in zip(df['Datetime'],df['Status'],df['Message'])
    ]

    helpers.bulk(es, data)

# %% [markdown]
# ## Main

# %% [markdown]
# ### 1. Spark Sesion 생성 및 Spark Data Frame으로 Data Read

# %%
spark = SparkSession.builder.master('local[2]').appName('airflow log test').getOrCreate()    
data = spark.read.text("hdfs://localhost:9870//airflow_logs/scheduler/2022-02-06/MySQL_to_CSV.py.log") # change path # change path

# %%
type(data)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
for i in data.collect():
    print(i)
# Out:
# Row(value='[2022-02-06 08:05:25,949] {processor.py:163} INFO - Started process (PID=688) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:05:26,052] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:05:26,098] {logging_mixin.py:109} INFO - [2022-02-06 08:05:26,063] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:05:56,267] {logging_mixin.py:109} INFO - [2022-02-06 08:05:56,229] {timeout.py:36} ERROR - Process timed out, PID: 688')
# Row(value='[2022-02-06 08:05:56,702] {logging_mixin.py:109} INFO - [2022-02-06 08:05:56,296] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 52, in <module>')
# Row(value='    from pandas.core.api import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/api.py", line 29, in <module>')
# Row(value='    from pandas.core.groupby import Grouper, NamedAgg')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>')
# Row(value='    from pandas.core.groupby.generic import DataFrameGroupBy, NamedAgg, SeriesGroupBy')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/groupby/generic.py", line 57, in <module>')
# Row(value='    from pandas.core.aggregation import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/aggregation.py", line 27, in <module>')
# Row(value='    from pandas.core.series import FrameOrSeriesUnion, Series')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/series.py", line 95, in <module>')
# Row(value='    import pandas.plotting')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/plotting/__init__.py", line 66, in <module>')
# Row(value='    from pandas.plotting._misc import (')
# Row(value='  File "<frozen importlib._bootstrap>", line 983, in _find_and_load')
# Row(value='  File "<frozen importlib._bootstrap>", line 963, in _find_and_load_unlocked')
# Row(value='  File "<frozen importlib._bootstrap>", line 906, in _find_spec')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 1280, in find_spec')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 1252, in _get_spec')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 1364, in find_spec')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 81, in _path_stat')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 688')
# Row(value='[2022-02-06 08:05:57,389] {processor.py:668} INFO - Deactivated 1 DAGs which are no longer present in /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:05:57,418] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:05:57,817] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 31.996 seconds')
# Row(value='[2022-02-06 08:09:22,824] {processor.py:163} INFO - Started process (PID=980) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:09:22,938] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:09:22,999] {logging_mixin.py:109} INFO - [2022-02-06 08:09:22,999] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:09:53,199] {logging_mixin.py:109} INFO - [2022-02-06 08:09:53,144] {timeout.py:36} ERROR - Process timed out, PID: 980')
# Row(value='[2022-02-06 08:09:53,543] {logging_mixin.py:109} INFO - [2022-02-06 08:09:53,238] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 52, in <module>')
# Row(value='    from pandas.core.api import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/api.py", line 15, in <module>')
# Row(value='    from pandas.core.arrays import Categorical')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/__init__.py", line 8, in <module>')
# Row(value='    from pandas.core.arrays.datetimes import DatetimeArray')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py", line 49, in <module>')
# Row(value='    from pandas.core.arrays import datetimelike as dtl')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/datetimelike.py", line 66, in <module>')
# Row(value='    from pandas.tseries import frequencies')
# Row(value='  File "<frozen importlib._bootstrap>", line 983, in _find_and_load')
# Row(value='  File "<frozen importlib._bootstrap>", line 963, in _find_and_load_unlocked')
# Row(value='  File "<frozen importlib._bootstrap>", line 906, in _find_spec')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 1280, in find_spec')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 1252, in _get_spec')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 1382, in find_spec')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 59, in _path_join')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 980')
# Row(value='[2022-02-06 08:09:54,106] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:09:54,590] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 31.955 seconds')
# Row(value='[2022-02-06 08:12:35,735] {processor.py:163} INFO - Started process (PID=1200) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:12:35,834] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:12:35,889] {logging_mixin.py:109} INFO - [2022-02-06 08:12:35,888] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:13:06,103] {logging_mixin.py:109} INFO - [2022-02-06 08:13:06,101] {timeout.py:36} ERROR - Process timed out, PID: 1200')
# Row(value='[2022-02-06 08:13:06,455] {logging_mixin.py:109} INFO - [2022-02-06 08:13:06,177] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 52, in <module>')
# Row(value='    from pandas.core.api import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/api.py", line 15, in <module>')
# Row(value='    from pandas.core.arrays import Categorical')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/__init__.py", line 7, in <module>')
# Row(value='    from pandas.core.arrays.categorical import Categorical')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/categorical.py", line 44, in <module>')
# Row(value='    from pandas.core.accessor import PandasDelegate, delegate_names')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/accessor.py", line 159, in <module>')
# Row(value='    class CachedAccessor:')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/accessor.py", line 183, in CachedAccessor')
# Row(value='    def __get__(self, obj, cls):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 1200')
# Row(value='[2022-02-06 08:13:07,318] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:13:07,858] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 32.313 seconds')
# Row(value='[2022-02-06 08:16:24,981] {processor.py:163} INFO - Started process (PID=1453) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:16:25,107] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:16:25,119] {logging_mixin.py:109} INFO - [2022-02-06 08:16:25,119] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:16:55,468] {logging_mixin.py:109} INFO - [2022-02-06 08:16:55,391] {timeout.py:36} ERROR - Process timed out, PID: 1453')
# Row(value='[2022-02-06 08:16:55,932] {logging_mixin.py:109} INFO - [2022-02-06 08:16:55,538] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 52, in <module>')
# Row(value='    from pandas.core.api import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/api.py", line 15, in <module>')
# Row(value='    from pandas.core.arrays import Categorical')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/__init__.py", line 6, in <module>')
# Row(value='    from pandas.core.arrays.boolean import BooleanArray')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/boolean.py", line 28, in <module>')
# Row(value='    from .masked import BaseMaskedArray, BaseMaskedDtype')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/masked.py", line 19, in <module>')
# Row(value='    from pandas.core import nanops')
# Row(value='  File "<frozen importlib._bootstrap>", line 983, in _find_and_load')
# Row(value='  File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked')
# Row(value='  File "<frozen importlib._bootstrap>", line 677, in _load_unlocked')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 724, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 857, in get_code')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 525, in _compile_bytecode')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 1453')
# Row(value='[2022-02-06 08:16:56,989] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:16:57,671] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 32.959 seconds')
# Row(value='[2022-02-06 08:20:40,009] {processor.py:163} INFO - Started process (PID=1733) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:20:40,115] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:20:40,204] {logging_mixin.py:109} INFO - [2022-02-06 08:20:40,204] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:21:10,347] {logging_mixin.py:109} INFO - [2022-02-06 08:21:10,345] {timeout.py:36} ERROR - Process timed out, PID: 1733')
# Row(value='[2022-02-06 08:21:10,843] {logging_mixin.py:109} INFO - [2022-02-06 08:21:10,450] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 52, in <module>')
# Row(value='    from pandas.core.api import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/api.py", line 15, in <module>')
# Row(value='    from pandas.core.arrays import Categorical')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>')
# Row(value='    from pandas.core.arrays.base import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/base.py", line 28, in <module>')
# Row(value='    from pandas.core import ops')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/ops/__init__.py", line 38, in <module>')
# Row(value='    from pandas.core.ops.methods import (  # noqa:F401')
# Row(value='  File "<frozen importlib._bootstrap>", line 983, in _find_and_load')
# Row(value='  File "<frozen importlib._bootstrap>", line 963, in _find_and_load_unlocked')
# Row(value='  File "<frozen importlib._bootstrap>", line 906, in _find_spec')
# Row(value='  File "<frozen importlib._bootstrap>", line 719, in find_spec')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 1733')
# Row(value='[2022-02-06 08:21:11,775] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:21:12,325] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 32.600 seconds')
# Row(value='[2022-02-06 08:25:31,868] {processor.py:163} INFO - Started process (PID=2047) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:25:31,986] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:25:32,052] {logging_mixin.py:109} INFO - [2022-02-06 08:25:32,028] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:26:02,257] {logging_mixin.py:109} INFO - [2022-02-06 08:26:02,167] {timeout.py:36} ERROR - Process timed out, PID: 2047')
# Row(value='[2022-02-06 08:26:02,759] {logging_mixin.py:109} INFO - [2022-02-06 08:26:02,312] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 52, in <module>')
# Row(value='    from pandas.core.api import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/api.py", line 15, in <module>')
# Row(value='    from pandas.core.arrays import Categorical')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>')
# Row(value='    from pandas.core.arrays.base import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/arrays/base.py", line 28, in <module>')
# Row(value='    from pandas.core import ops')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/ops/__init__.py", line 22, in <module>')
# Row(value='    from pandas.core.ops.array_ops import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/ops/array_ops.py", line 13, in <module>')
# Row(value='    from pandas._libs import Timedelta, Timestamp, lib, ops as libops')
# Row(value='  File "pandas/_libs/ops.pyx", line 1, in init pandas._libs.ops')
# Row(value='  File "<frozen importlib._bootstrap>", line 194, in _lock_unlock_module')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 2047')
# Row(value='[2022-02-06 08:26:03,972] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:26:04,691] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 32.923 seconds')
# Row(value='[2022-02-06 08:28:52,412] {processor.py:163} INFO - Started process (PID=2274) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:28:52,437] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:28:52,483] {logging_mixin.py:109} INFO - [2022-02-06 08:28:52,465] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:29:22,861] {logging_mixin.py:109} INFO - [2022-02-06 08:29:22,755] {timeout.py:36} ERROR - Process timed out, PID: 2274')
# Row(value='[2022-02-06 08:29:23,284] {logging_mixin.py:109} INFO - [2022-02-06 08:29:22,982] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 30, in <module>')
# Row(value='    from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/__init__.py", line 13, in <module>')
# Row(value='    from pandas._libs.interval import Interval')
# Row(value='  File "pandas/_libs/intervaltree.pxi", line 7, in init pandas._libs.interval')
# Row(value='  File "pandas/_libs/algos.pyx", line 51, in init pandas._libs.algos')
# Row(value='  File "<frozen importlib._bootstrap>", line 1009, in _handle_fromlist')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 2274')
# Row(value='[2022-02-06 08:29:24,612] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:29:25,576] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 33.281 seconds')
# Row(value='[2022-02-06 08:30:34,551] {processor.py:163} INFO - Started process (PID=2383) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:30:34,580] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:30:34,647] {logging_mixin.py:109} INFO - [2022-02-06 08:30:34,646] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:31:04,773] {logging_mixin.py:109} INFO - [2022-02-06 08:31:04,745] {timeout.py:36} ERROR - Process timed out, PID: 2383')
# Row(value='[2022-02-06 08:31:05,174] {logging_mixin.py:109} INFO - [2022-02-06 08:31:04,852] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 52, in <module>')
# Row(value='    from pandas.core.api import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/api.py", line 6, in <module>')
# Row(value='    from pandas.core.dtypes.dtypes import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py", line 27, in <module>')
# Row(value='    from pandas.core.dtypes.base import ExtensionDtype, register_extension_dtype')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/core/dtypes/base.py", line 10, in <module>')
# Row(value='    from pandas.errors import AbstractMethodError')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/errors/__init__.py", line 43, in <module>')
# Row(value='    class ParserError(ValueError):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 2383')
# Row(value='[2022-02-06 08:31:06,204] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:31:06,859] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 32.416 seconds')
# Row(value='[2022-02-06 08:35:35,836] {processor.py:163} INFO - Started process (PID=2732) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:35:36,009] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:35:36,077] {logging_mixin.py:109} INFO - [2022-02-06 08:35:36,038] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:36:06,413] {logging_mixin.py:109} INFO - [2022-02-06 08:36:06,411] {timeout.py:36} ERROR - Process timed out, PID: 2732')
# Row(value='[2022-02-06 08:36:06,765] {logging_mixin.py:109} INFO - [2022-02-06 08:36:06,563] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 30, in <module>')
# Row(value='    from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/__init__.py", line 13, in <module>')
# Row(value='    from pandas._libs.interval import Interval')
# Row(value='  File "pandas/_libs/intervaltree.pxi", line 7, in init pandas._libs.interval')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 2732')
# Row(value='[2022-02-06 08:36:07,957] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:36:08,747] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 33.151 seconds')
# Row(value='[2022-02-06 08:40:26,947] {processor.py:163} INFO - Started process (PID=3031) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:40:27,073] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:40:27,242] {logging_mixin.py:109} INFO - [2022-02-06 08:40:27,242] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:40:57,572] {logging_mixin.py:109} INFO - [2022-02-06 08:40:57,448] {timeout.py:36} ERROR - Process timed out, PID: 3031')
# Row(value='[2022-02-06 08:40:58,140] {logging_mixin.py:109} INFO - [2022-02-06 08:40:57,757] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 30, in <module>')
# Row(value='    from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/__init__.py", line 13, in <module>')
# Row(value='    from pandas._libs.interval import Interval')
# Row(value='  File "pandas/_libs/interval.pyx", line 1, in init pandas._libs.interval')
# Row(value='  File "pandas/_libs/hashtable.pyx", line 1, in init pandas._libs.hashtable')
# Row(value='  File "pandas/_libs/missing.pyx", line 1, in init pandas._libs.missing')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/tslibs/__init__.py", line 35, in <module>')
# Row(value='    from .period import IncompatibleFrequency, Period')
# Row(value='  File "<frozen importlib._bootstrap>", line 416, in parent')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 3031')
# Row(value='[2022-02-06 08:40:59,204] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:40:59,925] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 33.340 seconds')
# Row(value='[2022-02-06 08:42:17,206] {processor.py:163} INFO - Started process (PID=3155) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:42:17,245] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:42:17,451] {logging_mixin.py:109} INFO - [2022-02-06 08:42:17,451] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:42:47,849] {logging_mixin.py:109} INFO - [2022-02-06 08:42:47,847] {timeout.py:36} ERROR - Process timed out, PID: 3155')
# Row(value='[2022-02-06 08:42:48,447] {logging_mixin.py:109} INFO - [2022-02-06 08:42:48,052] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 30, in <module>')
# Row(value='    from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/__init__.py", line 13, in <module>')
# Row(value='    from pandas._libs.interval import Interval')
# Row(value='  File "pandas/_libs/interval.pyx", line 1, in init pandas._libs.interval')
# Row(value='  File "pandas/_libs/hashtable.pyx", line 1, in init pandas._libs.hashtable')
# Row(value='  File "pandas/_libs/missing.pyx", line 1, in init pandas._libs.missing')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/tslibs/__init__.py", line 30, in <module>')
# Row(value='    from .conversion import OutOfBoundsTimedelta, localize_pydatetime')
# Row(value='  File "pandas/_libs/tslibs/conversion.pyx", line 58, in init pandas._libs.tslibs.conversion')
# Row(value='  File "pandas/_libs/tslibs/parsing.pyx", line 1, in init pandas._libs.tslibs.parsing')
# Row(value='  File "pandas/_libs/tslibs/offsets.pyx", line 1, in init pandas._libs.tslibs.offsets')
# Row(value='  File "pandas/_libs/tslibs/timestamps.pyx", line 47, in init pandas._libs.tslibs.timestamps')
# Row(value='  File "pandas/_libs/tslibs/fields.pyx", line 16, in init pandas._libs.tslibs.fields')
# Row(value='  File "<frozen importlib._bootstrap>", line 978, in _find_and_load')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 3155')
# Row(value='[2022-02-06 08:42:49,698] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:42:50,410] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 33.610 seconds')
# Row(value='[2022-02-06 08:44:07,924] {processor.py:163} INFO - Started process (PID=3267) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:44:08,101] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:44:08,248] {logging_mixin.py:109} INFO - [2022-02-06 08:44:08,248] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:44:38,507] {logging_mixin.py:109} INFO - [2022-02-06 08:44:38,424] {timeout.py:36} ERROR - Process timed out, PID: 3267')
# Row(value='[2022-02-06 08:44:39,149] {logging_mixin.py:109} INFO - [2022-02-06 08:44:38,811] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 30, in <module>')
# Row(value='    from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/__init__.py", line 13, in <module>')
# Row(value='    from pandas._libs.interval import Interval')
# Row(value='  File "pandas/_libs/interval.pyx", line 1, in init pandas._libs.interval')
# Row(value='  File "pandas/_libs/hashtable.pyx", line 1, in init pandas._libs.hashtable')
# Row(value='  File "pandas/_libs/missing.pyx", line 1, in init pandas._libs.missing')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/tslibs/__init__.py", line 30, in <module>')
# Row(value='    from .conversion import OutOfBoundsTimedelta, localize_pydatetime')
# Row(value='  File "pandas/_libs/tslibs/conversion.pyx", line 58, in init pandas._libs.tslibs.conversion')
# Row(value='  File "pandas/_libs/tslibs/parsing.pyx", line 1, in init pandas._libs.tslibs.parsing')
# Row(value='  File "pandas/_libs/tslibs/offsets.pyx", line 1, in init pandas._libs.tslibs.offsets')
# Row(value='  File "pandas/_libs/tslibs/timestamps.pyx", line 47, in init pandas._libs.tslibs.timestamps')
# Row(value='  File "pandas/_libs/tslibs/fields.pyx", line 40, in init pandas._libs.tslibs.fields')
# Row(value='  File "pandas/_libs/tslibs/strptime.pyx", line 1, in init pandas._libs.tslibs.strptime')
# Row(value='  File "<frozen importlib._bootstrap>", line 194, in _lock_unlock_module')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 3267')
# Row(value='[2022-02-06 08:44:40,450] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:44:41,462] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 33.816 seconds')
# Row(value='[2022-02-06 08:45:57,931] {processor.py:163} INFO - Started process (PID=3388) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:45:58,030] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:45:58,091] {logging_mixin.py:109} INFO - [2022-02-06 08:45:58,090] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:46:28,307] {logging_mixin.py:109} INFO - [2022-02-06 08:46:28,219] {timeout.py:36} ERROR - Process timed out, PID: 3388')
# Row(value='[2022-02-06 08:46:28,835] {logging_mixin.py:109} INFO - [2022-02-06 08:46:28,502] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 30, in <module>')
# Row(value='    from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/__init__.py", line 13, in <module>')
# Row(value='    from pandas._libs.interval import Interval')
# Row(value='  File "pandas/_libs/interval.pyx", line 1, in init pandas._libs.interval')
# Row(value='  File "pandas/_libs/hashtable.pyx", line 1, in init pandas._libs.hashtable')
# Row(value='  File "pandas/_libs/missing.pyx", line 1, in init pandas._libs.missing')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/tslibs/__init__.py", line 30, in <module>')
# Row(value='    from .conversion import OutOfBoundsTimedelta, localize_pydatetime')
# Row(value='  File "pandas/_libs/tslibs/conversion.pyx", line 58, in init pandas._libs.tslibs.conversion')
# Row(value='  File "pandas/_libs/tslibs/parsing.pyx", line 1, in init pandas._libs.tslibs.parsing')
# Row(value='  File "pandas/_libs/tslibs/offsets.pyx", line 1, in init pandas._libs.tslibs.offsets')
# Row(value='  File "pandas/_libs/tslibs/timedeltas.pyx", line 1471, in init pandas._libs.tslibs.timedeltas')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/core/getlimits.py", line 498, in __init__')
# Row(value='    def __init__(self, int_type):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 3388')
# Row(value='[2022-02-06 08:46:30,217] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:46:31,425] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 33.606 seconds')
# Row(value='[2022-02-06 08:47:59,572] {processor.py:163} INFO - Started process (PID=3514) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:47:59,755] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:47:59,868] {logging_mixin.py:109} INFO - [2022-02-06 08:47:59,868] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:48:30,199] {logging_mixin.py:109} INFO - [2022-02-06 08:48:30,115] {timeout.py:36} ERROR - Process timed out, PID: 3514')
# Row(value='[2022-02-06 08:48:30,835] {logging_mixin.py:109} INFO - [2022-02-06 08:48:30,291] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 30, in <module>')
# Row(value='    from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/__init__.py", line 13, in <module>')
# Row(value='    from pandas._libs.interval import Interval')
# Row(value='  File "pandas/_libs/interval.pyx", line 1, in init pandas._libs.interval')
# Row(value='  File "pandas/_libs/hashtable.pyx", line 1, in init pandas._libs.hashtable')
# Row(value='  File "pandas/_libs/missing.pyx", line 1, in init pandas._libs.missing')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/_libs/tslibs/__init__.py", line 30, in <module>')
# Row(value='    from .conversion import OutOfBoundsTimedelta, localize_pydatetime')
# Row(value='  File "pandas/_libs/tslibs/conversion.pyx", line 58, in init pandas._libs.tslibs.conversion')
# Row(value='  File "pandas/_libs/tslibs/parsing.pyx", line 1, in init pandas._libs.tslibs.parsing')
# Row(value='  File "<frozen importlib._bootstrap>", line 194, in _lock_unlock_module')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 3514')
# Row(value='[2022-02-06 08:48:32,276] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:48:32,856] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 33.531 seconds')
# Row(value='[2022-02-06 08:49:41,459] {processor.py:163} INFO - Started process (PID=3621) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:49:41,594] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 08:49:41,770] {logging_mixin.py:109} INFO - [2022-02-06 08:49:41,685] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 08:50:12,149] {logging_mixin.py:109} INFO - [2022-02-06 08:50:12,007] {timeout.py:36} ERROR - Process timed out, PID: 3621')
# ...
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 11, in <module>')
# Row(value='    __import__(dependency)')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/__init__.py", line 140, in <module>')
# Row(value='    from . import core')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/core/__init__.py", line 76, in <module>')
# Row(value='    from . import defchararray as char')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/core/defchararray.py", line 881, in <module>')
# Row(value='    @array_function_dispatch(_unary_op_dispatcher)')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/core/overrides.py", line 181, in decorator')
# Row(value="    source, filename='<__array_function__ internals>', mode='exec')")
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 27304')
# Row(value='[2022-02-06 16:06:15,111] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 16:06:17,154] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 45.895 seconds')
# Row(value='[2022-02-06 16:08:16,404] {processor.py:163} INFO - Started process (PID=27447) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 16:08:17,282] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 16:08:18,079] {logging_mixin.py:109} INFO - [2022-02-06 16:08:17,874] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 16:08:50,664] {logging_mixin.py:109} INFO - [2022-02-06 16:08:49,880] {timeout.py:36} ERROR - Process timed out, PID: 27447')
# Row(value='[2022-02-06 16:08:53,469] {logging_mixin.py:109} INFO - [2022-02-06 16:08:50,921] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 11, in <module>')
# Row(value='    __import__(dependency)')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/__init__.py", line 140, in <module>')
# Row(value='    from . import core')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/core/__init__.py", line 72, in <module>')
# Row(value='    from . import numeric')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/core/numeric.py", line 2122, in <module>')
# Row(value='    def allclose(a, b, rtol=1.e-5, atol=1.e-8, equal_nan=False):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/core/overrides.py", line 188, in decorator')
# Row(value='    exec(source_object, scope)')
# Row(value='  File "<__array_function__ internals>", line 2, in <module>')
# Row(value='  File "/usr/local/lib/python3.7/functools.py", line 60, in update_wrapper')
# Row(value='    getattr(wrapper, attr).update(getattr(wrapped, attr, {}))')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 27447')
# Row(value='[2022-02-06 16:09:02,956] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 16:09:05,973] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 51.771 seconds')
# Row(value='[2022-02-06 16:10:50,957] {processor.py:163} INFO - Started process (PID=27572) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 16:10:51,425] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 16:10:51,674] {logging_mixin.py:109} INFO - [2022-02-06 16:10:51,673] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 16:11:23,330] {logging_mixin.py:109} INFO - [2022-02-06 16:11:23,196] {timeout.py:36} ERROR - Process timed out, PID: 27572')
# Row(value='[2022-02-06 16:11:25,803] {logging_mixin.py:109} INFO - [2022-02-06 16:11:23,493] {dagbag.py:334} ERROR - Failed to import: /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='Traceback (most recent call last):')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/models/dagbag.py", line 331, in _load_modules_from_file')
# Row(value='    loader.exec_module(new_module)')
# Row(value='  File "<frozen importlib._bootstrap_external>", line 728, in exec_module')
# Row(value='  File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed')
# Row(value='  File "/opt/airflow/dags/MySQL_to_CSV.py", line 9, in <module>')
# Row(value='    import pandas as pd')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/pandas/__init__.py", line 11, in <module>')
# Row(value='    __import__(dependency)')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/__init__.py", line 140, in <module>')
# Row(value='    from . import core')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/core/__init__.py", line 22, in <module>')
# Row(value='    from . import multiarray')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/core/multiarray.py", line 12, in <module>')
# Row(value='    from . import overrides')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/numpy/core/overrides.py", line 7, in <module>')
# Row(value='    from numpy.core._multiarray_umath import (')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/dag_processing/manager.py", line 486, in _exit_gracefully')
# Row(value='    self.log.debug("Current Stacktrace is: %s", \'\\n\'.join(map(str, inspect.stack())))')
# Row(value='  File "/usr/local/lib/python3.7/inspect.py", line 1513, in stack')
# Row(value='    return getouterframes(sys._getframe(1), context)')
# Row(value='  File "/usr/local/lib/python3.7/inspect.py", line 1490, in getouterframes')
# Row(value='    frameinfo = (frame,) + getframeinfo(frame, context)')
# Row(value='  File "/usr/local/lib/python3.7/inspect.py", line 1464, in getframeinfo')
# Row(value='    lines, lnum = findsource(frame)')
# Row(value='  File "/usr/local/lib/python3.7/inspect.py", line 780, in findsource')
# Row(value='    module = getmodule(object, file)')
# Row(value='  File "/usr/local/lib/python3.7/inspect.py", line 739, in getmodule')
# Row(value='    f = getabsfile(module)')
# Row(value='  File "/usr/local/lib/python3.7/inspect.py", line 708, in getabsfile')
# Row(value='    _filename = getsourcefile(object) or getfile(object)')
# Row(value='  File "/usr/local/lib/python3.7/inspect.py", line 693, in getsourcefile')
# Row(value='    if os.path.exists(filename):')
# Row(value='  File "/usr/local/lib/python3.7/genericpath.py", line 19, in exists')
# Row(value='    os.stat(path)')
# Row(value='  File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='    raise AirflowTaskTimeout(self.error_message)')
# Row(value='airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 27572')
# Row(value='[2022-02-06 16:11:32,181] {processor.py:634} WARNING - No viable dags retrieved from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 16:11:36,490] {processor.py:171} INFO - Processing /opt/airflow/dags/MySQL_to_CSV.py took 46.735 seconds')
# Row(value='[2022-02-06 16:12:57,430] {processor.py:163} INFO - Started process (PID=27690) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 16:12:57,744] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 16:12:58,084] {logging_mixin.py:109} INFO - [2022-02-06 16:12:58,050] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 16:13:34,773] {logging_mixin.py:109} INFO - [2022-02-06 16:13:34,749] {timeout.py:36} ERROR - Process timed out, PID: 27690')
# Row(value='[2022-02-06 16:13:34,791] {logging_mixin.py:109} WARNING - Exception ignored in: <function WeakKeyDictionary.__init__.<locals>.remove at 0x4011fa00e0>')
# Row(value='[2022-02-06 16:13:34,802] {logging_mixin.py:109} WARNING - Traceback (most recent call last):')
# Row(value='[2022-02-06 16:13:34,910] {logging_mixin.py:109} WARNING -   File "/usr/local/lib/python3.7/weakref.py", line 358, in remove')
# Row(value='[2022-02-06 16:13:36,036] {logging_mixin.py:109} WARNING -     def remove(k, selfref=ref(self)):')
# Row(value='[2022-02-06 16:13:36,259] {logging_mixin.py:109} WARNING -   File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='[2022-02-06 16:13:36,544] {logging_mixin.py:109} WARNING -     raise AirflowTaskTimeout(self.error_message)')
# Row(value='[2022-02-06 16:13:36,666] {logging_mixin.py:109} WARNING - airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 27690')
# Row(value='[2022-02-06 16:15:39,239] {processor.py:163} INFO - Started process (PID=27797) to work on /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 16:15:39,277] {processor.py:620} INFO - Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue')
# Row(value='[2022-02-06 16:15:39,423] {logging_mixin.py:109} INFO - [2022-02-06 16:15:39,357] {dagbag.py:500} INFO - Filling up the DagBag from /opt/airflow/dags/MySQL_to_CSV.py')
# Row(value='[2022-02-06 16:16:10,158] {logging_mixin.py:109} INFO - [2022-02-06 16:16:10,157] {timeout.py:36} ERROR - Process timed out, PID: 27797')
# Row(value='[2022-02-06 16:16:10,318] {logging_mixin.py:109} WARNING - Exception ignored in: <function WeakKeyDictionary.__init__.<locals>.remove at 0x4011fa00e0>')
# Row(value='[2022-02-06 16:16:10,680] {logging_mixin.py:109} WARNING - Traceback (most recent call last):')
# Row(value='[2022-02-06 16:16:10,775] {logging_mixin.py:109} WARNING -   File "/usr/local/lib/python3.7/weakref.py", line 358, in remove')
# Row(value='[2022-02-06 16:16:11,915] {logging_mixin.py:109} WARNING -     def remove(k, selfref=ref(self)):')
# Row(value='[2022-02-06 16:16:12,084] {logging_mixin.py:109} WARNING -   File "/home/airflow/.local/lib/python3.7/site-packages/airflow/dag_processing/manager.py", line 486, in _exit_gracefully')
# Row(value='[2022-02-06 16:16:12,203] {logging_mixin.py:109} WARNING -     self.log.debug("Current Stacktrace is: %s", \'\\n\'.join(map(str, inspect.stack())))')
# Row(value='[2022-02-06 16:16:12,422] {logging_mixin.py:109} WARNING -   File "/usr/local/lib/python3.7/inspect.py", line 1513, in stack')
# Row(value='[2022-02-06 16:16:12,935] {logging_mixin.py:109} WARNING -     return getouterframes(sys._getframe(1), context)')
# Row(value='[2022-02-06 16:16:13,001] {logging_mixin.py:109} WARNING -   File "/usr/local/lib/python3.7/inspect.py", line 1490, in getouterframes')
# Row(value='[2022-02-06 16:16:13,279] {logging_mixin.py:109} WARNING -     frameinfo = (frame,) + getframeinfo(frame, context)')
# Row(value='[2022-02-06 16:16:13,658] {logging_mixin.py:109} WARNING -   File "/usr/local/lib/python3.7/inspect.py", line 1464, in getframeinfo')
# Row(value='[2022-02-06 16:16:14,230] {logging_mixin.py:109} WARNING -     lines, lnum = findsource(frame)')
# Row(value='[2022-02-06 16:16:14,562] {logging_mixin.py:109} WARNING -   File "/usr/local/lib/python3.7/inspect.py", line 780, in findsource')
# Row(value='[2022-02-06 16:16:15,011] {logging_mixin.py:109} WARNING -     module = getmodule(object, file)')
# Row(value='[2022-02-06 16:16:15,349] {logging_mixin.py:109} WARNING -   File "/usr/local/lib/python3.7/inspect.py", line 742, in getmodule')
# Row(value='[2022-02-06 16:16:15,437] {logging_mixin.py:109} WARNING -     os.path.realpath(f)] = module.__name__')
# Row(value='[2022-02-06 16:16:15,803] {logging_mixin.py:109} WARNING -   File "/usr/local/lib/python3.7/posixpath.py", line 395, in realpath')
# Row(value='[2022-02-06 16:16:16,019] {logging_mixin.py:109} WARNING -     path, ok = _joinrealpath(filename[:0], filename, {})')
# Row(value='[2022-02-06 16:16:16,322] {logging_mixin.py:109} WARNING -   File "/usr/local/lib/python3.7/posixpath.py", line 429, in _joinrealpath')
# Row(value='[2022-02-06 16:16:16,428] {logging_mixin.py:109} WARNING -     if not islink(newpath):')
# Row(value='[2022-02-06 16:16:16,765] {logging_mixin.py:109} WARNING -   File "/usr/local/lib/python3.7/posixpath.py", line 171, in islink')
# Row(value='[2022-02-06 16:16:17,081] {logging_mixin.py:109} WARNING -     st = os.lstat(path)')
# Row(value='[2022-02-06 16:16:17,398] {logging_mixin.py:109} WARNING -   File "/home/airflow/.local/lib/python3.7/site-packages/airflow/utils/timeout.py", line 37, in handle_timeout')
# Row(value='[2022-02-06 16:16:17,583] {logging_mixin.py:109} WARNING -     raise AirflowTaskTimeout(self.error_message)')
# Row(value='[2022-02-06 16:16:17,938] {logging_mixin.py:109} WARNING - airflow.exceptions.AirflowTaskTimeout: DagBag import timeout for /opt/airflow/dags/MySQL_to_CSV.py after 30.0s.')
# Row(value='Please take a look at these docs to improve your DAG import time:')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#top-level-python-code')
# Row(value='* https://airflow.apache.org/docs/apache-airflow/2.2.0/best-practices.html#reducing-dag-complexity, PID: 27797')

# %% [markdown]
# ### 2. Log Data Parsing 후 Pandas Data Frame 형태로 변형

# %%
dict_list = []
ts_pattern = re.compile(r'\[(\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2},\d{3})]') # timestamp

for index in range(len(data.collect()) - 1):
    row = data.collect()[index]['value']

    if ts_pattern.match(row):
         dict_list.append(parsing(row))
                
df = pd.DataFrame(dict_list)   # pandas DataFrame 변경   
df["Datetime"] = pd.to_datetime(df["Timestamp"],format="%Y-%m-%d %H:%M:%S", errors = 'coerce')

# %% [markdown]
# ### 3. es에 데이터 적재

# %%
index_name="airflow_log_2022-02-06"
index_name
# Out:
# 'airflow_log_2022-02-06'

# %%
bulk_insert("localhost", "9200", df, index_name) # host, port, data, index

# %% [markdown]
# ### 4.  es 데이터 저장 확인

# %%
es = Elasticsearch(host = 'localhost',port = '9200')
index = "test_ver0.6"
body = "select * from " + index_name

res = es.search(index=index_name)

# %%
res
# Out:
# {'took': 2,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1500, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'airflow_log_2022-02-06',
#     '_type': '_doc',
#     '_id': 'VUBj0H4BbTliU3W3TL5T',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-02-05T06:41:59',
#      'log-level': 'INFO',
#      'message': 'Started process (PID=218) to work on /opt/airflow/dags/MySQL_to_CSV.py'}},
#    {'_index': 'airflow_log_2022-02-06',
#     '_type': '_doc',
#     '_id': 'VkBj0H4BbTliU3W3TL5T',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-02-05T06:41:59',
#      'log-level': 'INFO',
#      'message': 'Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue'}},
#    {'_index': 'airflow_log_2022-02-06',
#     '_type': '_doc',
#     '_id': 'V0Bj0H4BbTliU3W3TL5T',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-02-05T06:41:59',
#      'log-level': 'INFO',
#      'message': '[2022-02-05 06:41:59,141] {dagbag.py:500} '}},
#    {'_index': 'airflow_log_2022-02-06',
#     '_type': '_doc',
#     '_id': 'WEBj0H4BbTliU3W3TL5T',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-02-05T06:42:06',
#      'log-level': 'INFO',
#      'message': "DAG(s) dict_keys(['MySQLTOCsv']) retrieved from /opt/airflow/dags/MySQL_to_CSV.py"}},
#    {'_index': 'airflow_log_2022-02-06',
#     '_type': '_doc',
#     '_id': 'WUBj0H4BbTliU3W3TL5T',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-02-05T06:42:11',
#      'log-level': 'INFO',
#      'message': '[2022-02-05 06:42:11,117] {dag.py:2389} '}},
#    {'_index': 'airflow_log_2022-02-06',
#     '_type': '_doc',
#     '_id': 'WkBj0H4BbTliU3W3TL5T',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-02-05T06:42:12',
#      'log-level': 'INFO',
#      'message': '[2022-02-05 06:42:12,117] {dag.py:2914} '}},
#    {'_index': 'airflow_log_2022-02-06',
#     '_type': '_doc',
#     '_id': 'W0Bj0H4BbTliU3W3TL5T',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-02-05T06:42:12',
#      'log-level': 'INFO',
#      'message': 'Processing /opt/airflow/dags/MySQL_to_CSV.py took 13.177 seconds'}},
#    {'_index': 'airflow_log_2022-02-06',
#     '_type': '_doc',
#     '_id': 'XEBj0H4BbTliU3W3TL5T',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-02-05T06:42:43',
#      'log-level': 'INFO',
#      'message': 'Started process (PID=339) to work on /opt/airflow/dags/MySQL_to_CSV.py'}},
#    {'_index': 'airflow_log_2022-02-06',
#     '_type': '_doc',
#     '_id': 'XUBj0H4BbTliU3W3TL5T',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-02-05T06:42:43',
#      'log-level': 'INFO',
#      'message': 'Processing file /opt/airflow/dags/MySQL_to_CSV.py for tasks to queue'}},
#    {'_index': 'airflow_log_2022-02-06',
#     '_type': '_doc',
#     '_id': 'XkBj0H4BbTliU3W3TL5T',
#     '_score': 1.0,
#     '_source': {'datetime': '2022-02-05T06:42:43',
#      'log-level': 'INFO',
#      'message': '[2022-02-05 06:42:43,204] {dagbag.py:500} '}}]}}

# %% [markdown]
# ### 5. spark stop

# %%
 spark.stop()
